# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

word_count = Counter(int_words)
total_words = len(words)

t = 1e-5
word_frecuency  =  dict()
drop_prob =  dict()

for word,count in word_count.items():
    frecuency = count/total_words
    word_frecuency[word] = frecuency
    drop_prob[word] = 1 - np.sqrt(t/frecuency)

discard_prob = 0.90
train_words = []
for word in int_words:
    if (drop_prob[word] < discard_prob):
        train_words.append(word)
    
print(total_words)
print(len(train_words))
# Out:
# 16680599
# 9032964

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
import random

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = random.randint(1, 5)
    
    if (idx - R) > 0:
        start = idx - R
    else:
        start = 0
        
    R += 1
    if (idx + R ) <= len(words):
        end = idx + R 
    else:
        end = len(words)
    
        
    return list(set(words[start:idx] + words[idx+1:end]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  300
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev = 0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 6.4431 0.1854 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 6.3935 0.1667 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.3103 0.1676 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 6.2943 0.1616 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 6.1393 0.1589 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 6.0184 0.1582 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 6.0326 0.1568 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.9002 0.1562 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.6841 0.1549 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4964 0.1540 sec/batch
# Nearest to known: stalking, keats, zealand, wallabies, lecter, generally, xinhua, sterling,
# Nearest to people: article, theme, perctarit, bad, europe, ahl, relevance, tune,
# Nearest to during: her, limitations, hands, xi, return, speed, demarco, stratosphere,
# Nearest to who: nuit, funkadelic, shortfalls, caa, prajna, smo, milking, charismatic,
# Nearest to new: implants, octagon, devour, scalars, micromachining, mccall, samir, defuse,
# Nearest to states: through, addition, chromodynamics, sacrifices, contributory, advanced, roles, volante,
# Nearest to three: asatru, careful, uganda, filesystems, incorrect, corsa, wakayama, sputtering,
# Nearest to these: pecos, qurra, turgot, maverick, thermo, enjoying, hanun, nationwide,
# Nearest to bill: indirectly, impression, mythbusters, roussillon, textbooks, trust, deirdre, petrel,
# Nearest to alternative: stimulates, omar, pleasurable, vitamins, celestine, kowloon, chorale, daphne,
# Nearest to arts: balls, planckian, tfl, slanted, roadmap, dionysius, polymer, judgment,
# Nearest to applied: microsoft, calculation, ensigns, inorganic, hydrides, updated, ney, shows,
# Nearest to file: almirante, bends, cdi, pearlman, crs, primetime, leeward, dozens,
# Nearest to derived: individual, movements, pappy, intentions, pains, sturmgewehr, various, dolores,
# Nearest to smith: edn, every, houteff, startled, separately, etat, dehydrogenase, population,
# Nearest to brother: minoans, thumbs, john, neurotoxin, disaster, throughout, hannes, sustaining,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4000 0.1550 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.2881 0.1525 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.1030 0.1522 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.1284 0.1515 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.0442 0.1513 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.9750 0.1503 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.8770 0.1496 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.8719 0.1471 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.8564 0.1465 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.8061 0.1450 sec/batch
# Nearest to known: zealand, stalking, wallabies, intellectuals, hitting, keats, sterling, bongos,
# Nearest to people: theme, bad, tune, europe, relevance, article, brief, ahl,
# Nearest to during: xi, her, hands, return, limitations, isaac, plan, demarco,
# Nearest to who: nuit, funkadelic, shortfalls, caa, prajna, smo, milking, charismatic,
# Nearest to new: implants, octagon, devour, scalars, micromachining, mccall, samir, auer,
# Nearest to states: roles, addition, chromodynamics, advanced, sacrifices, through, playboy, cenotaph,
# Nearest to three: asatru, uganda, careful, filesystems, incorrect, corsa, wakayama, sputtering,
# Nearest to these: pecos, qurra, turgot, maverick, thermo, hanun, enjoying, mich,
# Nearest to bill: impression, indirectly, trust, awards, textbooks, teams, metal, mastery,
# Nearest to alternative: pleasurable, omar, stimulates, threatened, atrocities, vitamins, displaying, kowloon,
# Nearest to arts: balls, tfl, slanted, planckian, judgment, roadmap, gdp, polymer,
# Nearest to applied: microsoft, calculation, shows, updated, parish, ensigns, ney, won,
# Nearest to file: bends, almirante, pearlman, dozens, retain, form, tennessee, officials,
# Nearest to derived: individual, intentions, movements, pappy, custody, traffic, pains, translations,
# Nearest to smith: edn, every, separately, houteff, startled, population, social, etat,
# Nearest to brother: minoans, disaster, thumbs, china, neurotoxin, throughout, california, john,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.7523 0.1445 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6173 0.1437 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.6773 0.1445 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.6460 0.1439 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.6562 0.1436 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.6669 0.1435 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.6086 0.1433 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.6556 0.1425 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.6041 0.1418 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.5953 0.1428 sec/batch
# Nearest to known: zealand, intellectuals, wallabies, lecter, stalking, sms, keats, assigning,
# Nearest to people: theme, bad, tune, europe, perctarit, classified, relevance, brief,
# Nearest to during: xi, return, isaac, her, stratosphere, amplification, polynesia, demarco,
# Nearest to who: nuit, funkadelic, prajna, shortfalls, caa, smo, milking, oxidizes,
# Nearest to new: implants, octagon, devour, scalars, samir, micromachining, mccall, gaines,
# Nearest to states: chromodynamics, roles, addition, collegiate, forecasting, constitutional, humanist, uppsala,
# Nearest to three: asatru, careful, uganda, filesystems, incorrect, corsa, wakayama, sputtering,
# Nearest to these: pecos, qurra, turgot, thermo, maverick, hanun, choreographed, mich,
# Nearest to bill: impression, textbooks, indirectly, awards, trust, superstitious, teams, mastery,
# Nearest to alternative: omar, atrocities, vitamins, pleasurable, stimulates, celestine, pinochet, threatened,
# Nearest to arts: balls, tfl, slanted, allege, planckian, roadmap, polymer, dionysius,
# Nearest to applied: microsoft, calculation, shows, updated, mu, suspensions, parish, disciples,
# Nearest to file: bends, almirante, form, dozens, hence, reviews, delivery, pearlman,
# Nearest to derived: individual, intentions, custody, pappy, pains, movements, dolores, called,
# Nearest to smith: edn, every, startled, unbeknownst, separately, etat, houteff, curl,
# Nearest to brother: minoans, thumbs, disaster, sustaining, neurotoxin, john, california, mike,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.5624 0.1421 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.5749 0.1407 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.5649 0.1403 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.5143 0.1410 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.5209 0.1410 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.5060 0.1407 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.5265 0.1402 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.5310 0.1403 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.4679 0.1473 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.3722 0.1393 sec/batch
# Nearest to known: intellectuals, zealand, stalking, lecter, wallabies, keats, sms, belt,
# Nearest to people: tune, theme, bad, europe, inspire, relevance, jirga, kushan,
# Nearest to during: xi, jure, return, her, isaac, staging, demarco, stratosphere,
# Nearest to who: nuit, funkadelic, prajna, shortfalls, caa, smo, milking, oxidizes,
# Nearest to new: implants, octagon, devour, scalars, samir, micromachining, mccall, caracas,
# Nearest to states: chromodynamics, constitutional, roles, addition, forecasting, collegiate, volante, treaties,
# Nearest to three: careful, asatru, uganda, incorrect, filesystems, corsa, wakayama, sputtering,
# Nearest to these: pecos, qurra, turgot, thermo, maverick, hanun, mich, enjoying,
# Nearest to bill: impression, awards, textbooks, indirectly, superstitious, module, teams, trust,
# Nearest to alternative: vitamins, omar, atrocities, stimulates, pleasurable, celestine, pinochet, kowloon,
# Nearest to arts: balls, tfl, allege, slanted, roadmap, planckian, polymer, dionysius,
# Nearest to applied: microsoft, calculation, mu, shows, marina, updated, research, disciples,
# Nearest to file: bends, almirante, form, dozens, hence, rom, separating, computing,
# Nearest to derived: individual, intentions, custody, pappy, pains, word, movements, translations,
# Nearest to smith: edn, etat, unbeknownst, startled, every, dehydrogenase, southwark, timeslot,
# Nearest to brother: minoans, thumbs, sustaining, mike, john, disaster, neurotoxin, unlucky,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.3804 0.1404 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.4502 0.1394 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.3984 0.1393 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.4783 0.1398 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.3689 0.1407 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.4260 0.1401 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.3897 0.1398 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.4224 0.1397 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.3375 0.1396 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.3929 0.1392 sec/batch
# Nearest to known: intellectuals, lecter, stalking, deriving, assigning, zealand, wallabies, keats,
# Nearest to people: europe, bad, tune, theme, inspire, kushan, jirga, classified,
# Nearest to during: xi, jure, war, return, her, stratosphere, demarco, herr,
# Nearest to who: funkadelic, nuit, prajna, shortfalls, caa, smo, milking, charismatic,
# Nearest to new: implants, octagon, devour, scalars, samir, mccall, separated, micromachining,
# Nearest to states: chromodynamics, constitutional, addition, forecasting, collegiate, uppsala, roles, volante,
# Nearest to three: careful, asatru, incorrect, uganda, filesystems, wakayama, corsa, sputtering,
# Nearest to these: pecos, qurra, maverick, turgot, thermo, hanun, typhon, enjoying,
# Nearest to bill: impression, awards, textbooks, superstitious, merle, sarcasm, trust, declared,
# Nearest to alternative: stimulates, vitamins, atrocities, omar, kowloon, pinochet, celestine, pleasurable,
# Nearest to arts: balls, tfl, allege, roadmap, slanted, planckian, polymer, dionysius,
# Nearest to applied: microsoft, calculation, shows, research, marina, updated, textrm, mu,
# Nearest to file: almirante, filename, bends, computing, form, dozens, rom, cdi,
# Nearest to derived: intentions, word, individual, custody, pappy, translations, weaken, pains,
# Nearest to smith: edn, etat, unbeknownst, brenda, every, startled, lynn, timeslot,
# Nearest to brother: minoans, thumbs, married, mike, john, hannes, kenjutsu, unlucky,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.3216 0.1407 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.2253 0.1399 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.3577 0.1393 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.3386 0.1395 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.3741 0.1397 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.3265 0.1395 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.2447 0.1401 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.3705 0.1396 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.2937 0.1394 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.3034 0.1391 sec/batch
# Nearest to known: deriving, zealand, intellectuals, lecter, keats, xxxviii, stalking, wallabies,
# Nearest to people: tune, soldiery, bad, kushan, polo, theme, europe, jirga,
# Nearest to during: jure, xi, war, return, against, demarco, cubans, captured,
# Nearest to who: nuit, funkadelic, prajna, shortfalls, caa, smo, charismatic, milking,
# Nearest to new: implants, octagon, devour, scalars, caracas, malta, samir, separated,
# Nearest to states: chromodynamics, constitutional, addition, collegiate, forecasting, roles, uppsala, treaties,
# Nearest to three: careful, asatru, incorrect, uganda, filesystems, wakayama, corsa, rud,
# Nearest to these: pecos, qurra, maverick, turgot, thermo, hanun, typhon, nationwide,
# Nearest to bill: impression, superstitious, declared, module, awards, wicklow, indirectly, elects,
# Nearest to alternative: stimulates, vitamins, kowloon, omar, atrocities, celestine, pinochet, pleasurable,
# Nearest to arts: balls, allege, tfl, roadmap, planckian, slanted, sciences, dionysius,
# Nearest to applied: microsoft, calculation, shows, research, marina, ensigns, updated, textrm,
# Nearest to file: almirante, bends, filename, computing, rom, cdi, ghz, spitz,
# Nearest to derived: word, custody, intentions, pappy, individual, numerals, weaken, called,
# Nearest to smith: edn, unbeknownst, brenda, etat, lynn, southwark, startled, chapman,
# Nearest to brother: minoans, married, thumbs, majesty, mike, hannes, john, sustaining,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.3284 0.1409 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.3294 0.1395 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.2716 0.1393 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.1827 0.1397 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.2499 0.1399 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.2574 0.1398 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.2274 0.1401 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.2790 0.1405 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.1461 0.1376 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.1574 0.1378 sec/batch
# Nearest to known: keats, intellectuals, xxxviii, deriving, zealand, wallabies, stalking, contemplation,
# Nearest to people: soldiery, tune, bad, polo, kushan, jirga, perctarit, theme,
# Nearest to during: jure, xi, stratosphere, demarco, included, war, return, hihat,
# Nearest to who: funkadelic, nuit, prajna, shortfalls, caa, smo, charismatic, karelia,
# Nearest to new: implants, octagon, devour, scalars, crude, separated, malta, caracas,
# Nearest to states: chromodynamics, vice, constitutional, uppsala, addition, humanist, forecasting, cenotaph,
# Nearest to three: careful, asatru, incorrect, uganda, filesystems, wakayama, corsa, rud,
# Nearest to these: pecos, qurra, maverick, turgot, thermo, hanun, typhon, nationwide,
# Nearest to bill: impression, awards, declared, module, superstitious, elects, chairman, textbooks,
# Nearest to alternative: vitamins, omar, kowloon, stimulates, celestine, pleasurable, atrocities, displaying,
# Nearest to arts: balls, tfl, roadmap, allege, sciences, planckian, mathematics, dionysius,
# Nearest to applied: microsoft, calculation, research, shows, generalizes, textrm, inorganic, updated,
# Nearest to file: filename, almirante, bends, rom, computing, ghz, cdi, delivery,
# Nearest to derived: word, pappy, intentions, numerals, custody, pains, translations, irritation,
# Nearest to smith: edn, lynn, brenda, unbeknownst, etat, chapman, william, updike,
# Nearest to brother: married, minoans, thumbs, majesty, mike, hannes, john, wife,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.2458 0.1393 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.2705 0.1379 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.2242 0.1375 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.3584 0.1379 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.2934 0.1378 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.2161 0.1378 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.0899 0.1376 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.2150 0.1377 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.2436 0.1379 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.2021 0.1378 sec/batch
# Nearest to known: xxxviii, lecter, deriving, wallabies, gallant, analyte, stalking, contemplation,
# Nearest to people: soldiery, bad, tune, classified, polo, perctarit, inspire, jirga,
# Nearest to during: jure, xi, included, demarco, war, charlemagne, hihat, ended,
# Nearest to who: funkadelic, nuit, caa, prajna, smo, shortfalls, karelia, charismatic,
# Nearest to new: implants, octagon, crude, devour, scalars, cement, caracas, separated,
# Nearest to states: chromodynamics, uppsala, addition, constitutional, cenotaph, collegiate, volante, vice,
# Nearest to three: asatru, uganda, careful, incorrect, filesystems, wakayama, corsa, rud,
# Nearest to these: pecos, qurra, maverick, turgot, nationwide, thermo, hanun, typhon,
# Nearest to bill: impression, elects, awards, module, chairman, textbooks, topeka, superstitious,
# Nearest to alternative: vitamins, kowloon, omar, stimulates, celestine, atrocities, pinochet, displaying,
# Nearest to arts: sciences, roadmap, tfl, allege, balls, dionysius, planckian, mathematics,
# Nearest to applied: microsoft, calculation, research, shows, generalizes, textrm, ensigns, inorganic,
# Nearest to file: filename, bends, almirante, rom, computing, spitz, ghz, reviews,
# Nearest to derived: word, pappy, intentions, numerals, custody, called, translations, disambiguation,
# Nearest to smith: edn, brenda, lynn, regis, kroeber, updike, zolt, chapman,
# Nearest to brother: married, minoans, majesty, thumbs, hannes, sustaining, foresee, mike,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.2329 0.1387 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.1628 0.1369 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 3.9407 0.1371 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.2223 0.1373 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.1254 0.1368 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.2245 0.1372 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.1878 0.1372 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.1577 0.1366 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.1878 0.1369 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.2495 0.1368 sec/batch
# Nearest to known: xxxviii, zealand, deriving, lecter, intellectuals, wallabies, contemplation, gallant,
# Nearest to people: soldiery, bad, perctarit, polo, jirga, softness, tune, kushan,
# Nearest to during: jure, demarco, xi, included, amplification, war, stratosphere, ended,
# Nearest to who: funkadelic, nuit, caa, prajna, smo, shortfalls, karelia, milking,
# Nearest to new: implants, octagon, crude, devour, cement, scalars, separated, caracas,
# Nearest to states: chromodynamics, uppsala, addition, collegiate, constitutional, volante, barents, cenotaph,
# Nearest to three: incorrect, asatru, uganda, careful, filesystems, wakayama, corsa, umpire,
# Nearest to these: pecos, maverick, qurra, turgot, nationwide, hanun, choreographed, thermo,
# Nearest to bill: impression, awards, module, senator, yukio, superstitious, bobby, textbooks,
# Nearest to alternative: kowloon, vitamins, omar, displaying, stimulates, pinochet, atrocities, skeptic,
# Nearest to arts: sciences, balls, dionysius, allege, polymer, roadmap, tfl, planckian,
# Nearest to applied: calculation, research, textrm, microsoft, generalizes, shows, suspensions, dialing,
# Nearest to file: filename, almirante, bends, rom, spitz, computing, reviews, cdi,
# Nearest to derived: word, pappy, intentions, numerals, called, disambiguation, custody, weaken,
# Nearest to smith: edn, brenda, zolt, lynn, chapman, regis, updike, kroeber,
# Nearest to brother: married, majesty, thumbs, minoans, hannes, sustaining, possession, adultery,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.1742 0.0953 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.0671 0.1397 sec/batch
# Epoch 2/10 Iteration: 9300 Avg. Training loss: 4.1190 0.1412 sec/batch
# Epoch 2/10 Iteration: 9400 Avg. Training loss: 4.0527 0.1415 sec/batch
# Epoch 2/10 Iteration: 9500 Avg. Training loss: 4.0887 0.1415 sec/batch
# Epoch 2/10 Iteration: 9600 Avg. Training loss: 4.0295 0.1421 sec/batch
# Epoch 2/10 Iteration: 9700 Avg. Training loss: 4.0961 0.1407 sec/batch
# Epoch 2/10 Iteration: 9800 Avg. Training loss: 4.0597 0.1410 sec/batch
# Epoch 2/10 Iteration: 9900 Avg. Training loss: 4.0397 0.1417 sec/batch
# Epoch 2/10 Iteration: 10000 Avg. Training loss: 4.1118 0.1418 sec/batch
# Nearest to known: zealand, deriving, xxxviii, intellectuals, lecter, wallabies, gallant, supper,
# Nearest to people: soldiery, bad, perctarit, jirga, kushan, polo, brin, learn,
# Nearest to during: jure, included, telescopic, demarco, ended, war, amplification, polices,
# Nearest to who: funkadelic, nuit, caa, prajna, smo, shortfalls, karelia, milking,
# Nearest to new: implants, octagon, devour, separated, crude, cement, scalars, caracas,
# Nearest to states: chromodynamics, uppsala, barents, gaut, cenotaph, constitutional, volante, collegiate,
# Nearest to three: incorrect, uganda, asatru, careful, filesystems, wakayama, corsa, rud,
# Nearest to these: pecos, maverick, qurra, turgot, nationwide, enjoying, hanun, thermo,
# Nearest to bill: impression, module, textbooks, loopholes, yukio, thro, elects, superstitious,
# Nearest to alternative: vitamins, medical, omar, kowloon, gooseberry, atrocities, displaying, chorale,
# Nearest to arts: sciences, balls, planckian, allege, tfl, roadmap, polymer, dionysius,
# Nearest to applied: generalizes, calculation, research, textrm, shows, suspensions, microsoft, inorganic,
# Nearest to file: filename, almirante, rom, ansi, reviews, bends, cdi, computing,
# Nearest to derived: word, pappy, numerals, intentions, custody, lazar, disambiguation, called,
# Nearest to smith: edn, zolt, brenda, kroeber, lynn, regis, chapman, hammerstein,
# Nearest to brother: married, majesty, thumbs, minoans, hannes, sustaining, foresee, demiurge,
# Epoch 2/10 Iteration: 10100 Avg. Training loss: 4.0602 0.1425 sec/batch
# Epoch 2/10 Iteration: 10200 Avg. Training loss: 4.0357 0.1424 sec/batch
# Epoch 2/10 Iteration: 10300 Avg. Training loss: 4.0368 0.1420 sec/batch
# Epoch 2/10 Iteration: 10400 Avg. Training loss: 3.9466 0.1417 sec/batch
# Epoch 2/10 Iteration: 10500 Avg. Training loss: 4.1011 0.1415 sec/batch
# Epoch 2/10 Iteration: 10600 Avg. Training loss: 4.0946 0.1410 sec/batch
# Epoch 2/10 Iteration: 10700 Avg. Training loss: 4.0741 0.1414 sec/batch
# Epoch 2/10 Iteration: 10800 Avg. Training loss: 4.0614 0.1417 sec/batch
# Epoch 2/10 Iteration: 10900 Avg. Training loss: 4.0957 0.1416 sec/batch
# Epoch 2/10 Iteration: 11000 Avg. Training loss: 4.1081 0.1412 sec/batch
# Nearest to known: zealand, wallabies, deriving, analyte, intellectuals, referred, gallant, supper,
# Nearest to people: soldiery, bad, perctarit, kushan, jirga, tune, smoke, learn,
# Nearest to during: jure, ended, demarco, polices, war, telescopic, included, crimean,
# Nearest to who: funkadelic, nuit, caa, prajna, shortfalls, milking, karelia, smo,
# Nearest to new: implants, octagon, separated, cement, devour, scalars, crude, caracas,
# Nearest to states: chromodynamics, cenotaph, barents, uppsala, volante, gaut, kingdom, addition,
# Nearest to three: incorrect, uganda, asatru, careful, wakayama, filesystems, corsa, rud,
# Nearest to these: pecos, maverick, qurra, enjoying, turgot, nationwide, thermo, hanun,
# Nearest to bill: impression, yukio, module, loopholes, bobby, textbooks, awards, superstitious,
# Nearest to alternative: vitamins, medical, kowloon, atrocities, gooseberry, chorale, omar, stimulates,
# Nearest to arts: sciences, planckian, tfl, balls, allege, dionysius, roadmap, polymer,
# Nearest to applied: generalizes, calculation, research, textrm, shows, inorganic, suspensions, ensigns,
# Nearest to file: filename, ansi, almirante, reviews, rom, cdi, maintainer, bends,
# Nearest to derived: word, pappy, numerals, custody, envisage, lazar, disambiguation, intentions,
# Nearest to smith: edn, kroeber, zolt, brenda, lynn, hammerstein, chapman, regis,
# Nearest to brother: majesty, minoans, thumbs, married, hannes, sustaining, adultery, foresee,
# Epoch 2/10 Iteration: 11100 Avg. Training loss: 4.0144 0.1424 sec/batch
# Epoch 2/10 Iteration: 11200 Avg. Training loss: 3.9448 0.1415 sec/batch
# Epoch 2/10 Iteration: 11300 Avg. Training loss: 3.8950 0.1416 sec/batch
# Epoch 2/10 Iteration: 11400 Avg. Training loss: 4.0755 0.1413 sec/batch
# Epoch 2/10 Iteration: 11500 Avg. Training loss: 3.9804 0.1412 sec/batch
# Epoch 2/10 Iteration: 11600 Avg. Training loss: 4.0176 0.1412 sec/batch
# Epoch 2/10 Iteration: 11700 Avg. Training loss: 3.9850 0.1410 sec/batch
# Epoch 2/10 Iteration: 11800 Avg. Training loss: 4.0129 0.1413 sec/batch
# Epoch 2/10 Iteration: 11900 Avg. Training loss: 4.0798 0.1418 sec/batch
# Epoch 2/10 Iteration: 12000 Avg. Training loss: 4.0278 0.1420 sec/batch
# Nearest to known: called, referred, analyte, zealand, wallabies, lecter, deriving, intellectuals,
# Nearest to people: soldiery, bad, perctarit, jirga, kushan, polo, smoke, softness,
# Nearest to during: jure, demarco, telescopic, polices, amplification, ended, early, included,
# Nearest to who: funkadelic, nuit, prajna, caa, milking, shortfalls, karelia, reconquer,
# Nearest to new: implants, octagon, cement, devour, separated, scalars, caracas, fend,
# Nearest to states: chromodynamics, volante, kingdom, cenotaph, uppsala, gaut, barents, addition,
# Nearest to three: incorrect, uganda, asatru, careful, wakayama, filesystems, corsa, rud,
# Nearest to these: pecos, maverick, qurra, enjoying, turgot, nationwide, choreographed, thermo,
# Nearest to bill: impression, loopholes, yukio, module, uninfected, awards, captained, merle,
# Nearest to alternative: vitamins, atrocities, omar, medical, kowloon, gooseberry, chorale, displaying,
# Nearest to arts: sciences, planckian, tfl, roadmap, allege, balls, renowned, dionysius,
# Nearest to applied: generalizes, textrm, calculation, research, shows, microsoft, suspensions, ensigns,
# Nearest to file: filename, ansi, almirante, reviews, maintainer, rom, cdi, spitz,
# Nearest to derived: word, pappy, lazar, envisage, numerals, custody, disambiguation, transcribed,
# Nearest to smith: edn, kroeber, lynn, zolt, hammerstein, regis, updike, chapman,
# Nearest to brother: majesty, thumbs, minoans, hannes, married, sustaining, adultery, demiurge,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.0362 0.1424 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.0147 0.1422 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.0961 0.1409 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 3.9734 0.1411 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 3.9997 0.1408 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.0419 0.1412 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.0503 0.1412 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 4.0808 0.1416 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 4.0061 0.1409 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 3.9001 0.1402 sec/batch
# Nearest to known: referred, called, zealand, wallabies, analyte, intellectuals, schine, lecter,
# Nearest to people: soldiery, perctarit, bad, jirga, kushan, softness, polo, learn,
# Nearest to during: jure, ended, demarco, early, telescopic, polices, crimean, end,
# Nearest to who: funkadelic, nuit, prajna, karelia, caa, milking, shortfalls, reconquer,
# Nearest to new: implants, octagon, cement, devour, crude, separated, caracas, scalars,
# Nearest to states: chromodynamics, gaut, volante, kingdom, barents, uppsala, cenotaph, addition,
# Nearest to three: incorrect, asatru, uganda, careful, wakayama, filesystems, corsa, rud,
# Nearest to these: pecos, maverick, qurra, enjoying, nationwide, turgot, thermo, hanun,
# Nearest to bill: impression, yukio, uninfected, merle, loopholes, bobby, module, captained,
# Nearest to alternative: medical, vitamins, atrocities, displaying, kowloon, gooseberry, omar, cryopreserved,
# Nearest to arts: sciences, planckian, tfl, roadmap, balls, allege, renowned, dionysius,
# Nearest to applied: generalizes, textrm, calculation, research, microsoft, shows, inorganic, ensigns,
# Nearest to file: filename, almirante, ansi, maintainer, reviews, name, cdi, bounding,
# Nearest to derived: word, pappy, numerals, custody, lazar, disambiguation, envisage, transcribed,
# Nearest to smith: edn, chapman, kroeber, zolt, regis, brenda, prep, updike,
# Nearest to brother: majesty, thumbs, adultery, hannes, minoans, married, demiurge, roger,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 3.9736 0.1420 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.0208 0.1409 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.0318 0.1413 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.0389 0.1415 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.0270 0.1410 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 3.9913 0.1400 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.0032 0.1404 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.0594 0.1401 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 3.9436 0.1402 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.0434 0.1402 sec/batch
# Nearest to known: referred, called, analyte, wallabies, zealand, supper, schine, lecter,
# Nearest to people: soldiery, perctarit, bad, jirga, learn, softness, kushan, smoke,
# Nearest to during: ended, jure, polices, end, telescopic, demarco, crimean, war,
# Nearest to who: nuit, funkadelic, caa, prajna, karelia, milking, shortfalls, reconquer,
# Nearest to new: octagon, implants, cement, devour, scalars, crude, caracas, separated,
# Nearest to states: chromodynamics, gaut, kingdom, uppsala, volante, barents, addition, cenotaph,
# Nearest to three: incorrect, asatru, uganda, careful, filesystems, wakayama, corsa, rud,
# Nearest to these: pecos, maverick, enjoying, qurra, nationwide, turgot, choreographed, hanun,
# Nearest to bill: impression, uninfected, loopholes, senator, captained, bobby, module, merle,
# Nearest to alternative: vitamins, medical, atrocities, displaying, omar, sem, cryopreserved, stimulates,
# Nearest to arts: planckian, sciences, tfl, roadmap, balls, dionysius, allege, tter,
# Nearest to applied: generalizes, textrm, calculation, inorganic, microsoft, shows, proctor, ensigns,
# Nearest to file: filename, ansi, maintainer, almirante, cdi, rom, reviews, form,
# Nearest to derived: pappy, word, numerals, disambiguation, lazar, envisage, custody, transcribed,
# Nearest to smith: edn, zolt, regis, brenda, kroeber, lynn, chapman, stroheim,
# Nearest to brother: majesty, thumbs, adultery, minoans, demiurge, hannes, married, gesch,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 3.9636 0.1410 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 3.8720 0.1398 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.0205 0.1404 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.0368 0.1406 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.0103 0.1401 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.0658 0.1402 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 3.9014 0.1406 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.0305 0.1407 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.0276 0.1405 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 3.9856 0.1394 sec/batch
# Nearest to known: called, referred, wallabies, analyte, supper, zealand, deriving, xxxviii,
# Nearest to people: soldiery, perctarit, bad, jirga, mulatto, learn, kushan, polo,
# Nearest to during: ended, end, jure, polices, crimean, war, telescopic, included,
# Nearest to who: nuit, funkadelic, caa, prajna, karelia, technologies, shortfalls, milking,
# Nearest to new: octagon, cement, implants, crude, devour, scalars, caracas, separated,
# Nearest to states: chromodynamics, cenotaph, kingdom, gaut, barents, uppsala, volante, nations,
# Nearest to three: incorrect, asatru, uganda, filesystems, wakayama, careful, rud, corsa,
# Nearest to these: pecos, maverick, enjoying, qurra, choreographed, nationwide, turgot, hanun,
# Nearest to bill: impression, uninfected, senator, loopholes, elects, captained, democratic, thro,
# Nearest to alternative: vitamins, omar, displaying, megali, chorale, atrocities, pinochet, gooseberry,
# Nearest to arts: sciences, planckian, tfl, roadmap, dionysius, balls, vibrant, renowned,
# Nearest to applied: textrm, generalizes, gillies, shows, ensigns, proctor, calculation, inorganic,
# Nearest to file: filename, ansi, maintainer, almirante, reviews, pl, enforce, bounding,
# Nearest to derived: pappy, word, numerals, custody, transcribed, lazar, envisage, niva,
# Nearest to smith: edn, zolt, lynn, regis, kroeber, brenda, hammerstein, chapman,
# Nearest to brother: majesty, carangi, adultery, married, thumbs, gesch, demiurge, minoans,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.0132 0.1418 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.0066 0.1406 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.0189 0.1396 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 3.8450 0.1414 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 3.9435 0.1402 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 3.9678 0.1399 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 3.9600 0.1388 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.0161 0.1389 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 3.7883 0.1388 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 3.8896 0.1392 sec/batch
# Nearest to known: called, referred, analyte, supper, zealand, xxxviii, huangdi, intellectuals,
# Nearest to people: soldiery, perctarit, jirga, bad, mulatto, polo, learn, americans,
# Nearest to during: ended, end, jure, polices, included, crimean, telescopic, early,
# Nearest to who: nuit, funkadelic, caa, prajna, technologies, shortfalls, reconquer, milking,
# Nearest to new: octagon, cement, implants, crude, devour, scalars, fend, caracas,
# Nearest to states: chromodynamics, kingdom, cenotaph, gaut, vice, uppsala, volante, behaving,
# Nearest to three: incorrect, asatru, uganda, wakayama, filesystems, careful, corsa, rud,
# Nearest to these: pecos, maverick, enjoying, qurra, choreographed, hanun, nationwide, typhon,
# Nearest to bill: impression, senator, uninfected, loopholes, captained, bobby, democratic, thro,
# Nearest to alternative: omar, chorale, vitamins, gooseberry, medical, displaying, megali, incubated,
# Nearest to arts: sciences, planckian, tfl, dionysius, roadmap, tter, vibrant, balls,
# Nearest to applied: generalizes, textrm, gillies, proctor, inorganic, ensigns, shows, calculation,
# Nearest to file: filename, ansi, maintainer, almirante, reviews, rom, pl, bounding,
# Nearest to derived: pappy, numerals, word, transcribed, envisage, lazar, disambiguation, custody,
# Nearest to smith: edn, zolt, lynn, regis, brenda, prep, kroeber, stroheim,
# Nearest to brother: majesty, carangi, demiurge, adultery, thumbs, minoans, gesch, married,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 3.9672 0.1399 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.0303 0.1387 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 3.9683 0.1385 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.0877 0.1385 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.0851 0.1387 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.0105 0.1391 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 3.8125 0.1383 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 3.9924 0.1377 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 3.9445 0.1380 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 3.9599 0.1382 sec/batch
# Nearest to known: called, referred, analyte, regarded, xxxviii, wallabies, considered, huangdi,
# Nearest to people: soldiery, perctarit, learn, jirga, bad, taiwan, deemphasized, tune,
# Nearest to during: end, ended, included, jure, polices, crimean, alemannia, telescopic,
# Nearest to who: nuit, funkadelic, caa, technologies, prajna, reconquer, karelia, milking,
# Nearest to new: cement, octagon, implants, devour, crude, fend, scalars, caracas,
# Nearest to states: chromodynamics, gaut, kingdom, cenotaph, volante, nations, barents, addition,
# Nearest to three: incorrect, uganda, asatru, wakayama, filesystems, rud, corsa, careful,
# Nearest to these: pecos, maverick, enjoying, qurra, choreographed, nationwide, hanun, praenomen,
# Nearest to bill: impression, uninfected, loopholes, senator, thro, captained, bobby, merle,
# Nearest to alternative: chorale, gooseberry, vitamins, omar, sem, displaying, megali, instinctively,
# Nearest to arts: sciences, tfl, dionysius, planckian, roadmap, vibrant, balls, allege,
# Nearest to applied: generalizes, textrm, gillies, inorganic, suspensions, shows, proctor, ensigns,
# Nearest to file: filename, maintainer, ansi, almirante, pl, spitz, reviews, officials,
# Nearest to derived: pappy, word, numerals, envisage, disambiguation, lazar, ventris, xiongnu,
# Nearest to smith: edn, zolt, kroeber, lynn, regis, bettors, brenda, kanons,
# Nearest to brother: carangi, majesty, stillborn, adultery, minoans, froissart, hannes, demiurge,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.0384 0.1395 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 3.9828 0.1379 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 3.6881 0.1384 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 3.9471 0.1388 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 3.9150 0.1387 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 3.9580 0.1382 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 3.9873 0.1383 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 3.8933 0.1383 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.0007 0.1386 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 3.9632 0.1382 sec/batch
# Nearest to known: called, referred, analyte, considered, regarded, xxxviii, supper, wallabies,
# Nearest to people: soldiery, perctarit, kills, learn, inhabitants, bad, mulatto, taiwan,
# Nearest to during: end, ended, jure, included, telescopic, polices, early, alemannia,
# Nearest to who: nuit, funkadelic, caa, technologies, prajna, reconquer, karelia, shortfalls,
# Nearest to new: cement, octagon, implants, devour, crude, fend, micromachining, scalars,
# Nearest to states: chromodynamics, kingdom, gaut, volante, cenotaph, barents, behaving, nations,
# Nearest to three: incorrect, uganda, asatru, wakayama, filesystems, rud, corsa, careful,
# Nearest to these: pecos, maverick, enjoying, qurra, choreographed, nationwide, hanun, typhon,
# Nearest to bill: impression, uninfected, senator, loopholes, thro, yukio, captained, bobby,
# Nearest to alternative: chorale, gooseberry, displaying, sem, omar, medical, vitamins, earnest,
# Nearest to arts: sciences, dionysius, tfl, sport, martial, roadmap, vibrant, allege,
# Nearest to applied: generalizes, textrm, gillies, inorganic, proctor, suspensions, ensigns, university,
# Nearest to file: filename, maintainer, ansi, pl, format, spitz, rom, reviews,
# Nearest to derived: pappy, disambiguation, envisage, datur, numerals, lazar, word, ventris,
# Nearest to smith: edn, zolt, lynn, kroeber, amyraut, regis, brenda, bettors,
# Nearest to brother: adultery, majesty, carangi, stillborn, fulvia, minoans, demiurge, froissart,
# Epoch 3/10 Iteration: 18100 Avg. Training loss: 4.0199 0.0497 sec/batch
# Epoch 3/10 Iteration: 18200 Avg. Training loss: 3.8979 0.1389 sec/batch
# Epoch 3/10 Iteration: 18300 Avg. Training loss: 3.9485 0.1389 sec/batch
# Epoch 3/10 Iteration: 18400 Avg. Training loss: 3.8770 0.1388 sec/batch
# Epoch 3/10 Iteration: 18500 Avg. Training loss: 3.9070 0.1380 sec/batch
# Epoch 3/10 Iteration: 18600 Avg. Training loss: 3.8892 0.1383 sec/batch
# Epoch 3/10 Iteration: 18700 Avg. Training loss: 3.8741 0.1381 sec/batch
# Epoch 3/10 Iteration: 18800 Avg. Training loss: 3.9228 0.1388 sec/batch
# Epoch 3/10 Iteration: 18900 Avg. Training loss: 3.8472 0.1382 sec/batch
# Epoch 3/10 Iteration: 19000 Avg. Training loss: 3.9055 0.1383 sec/batch
# Nearest to known: referred, called, considered, analyte, regarded, zealand, dehydroepiandrosterone, einhorn,
# Nearest to people: soldiery, perctarit, kills, mulatto, jirga, learn, autodidacts, polo,
# Nearest to during: end, ended, telescopic, included, develops, alemannia, polices, amplification,
# Nearest to who: nuit, funkadelic, caa, technologies, prajna, karelia, reconquer, shortfalls,
# Nearest to new: octagon, cement, implants, devour, fend, separated, micromachining, scalars,
# Nearest to states: chromodynamics, kingdom, gaut, cenotaph, volante, uppsala, america, barents,
# Nearest to three: incorrect, uganda, asatru, wakayama, filesystems, rud, corsa, kariba,
# Nearest to these: pecos, maverick, enjoying, nationwide, qurra, choreographed, hanun, typhon,
# Nearest to bill: impression, uninfected, senator, loopholes, thro, bobby, yukio, captained,
# Nearest to alternative: medical, chorale, vitamins, gooseberry, atrocities, omar, earnest, treating,
# Nearest to arts: sciences, tfl, sport, vibrant, dionysius, planckian, allege, roadmap,
# Nearest to applied: generalizes, inorganic, textrm, gillies, proctor, suspensions, amici, shows,
# Nearest to file: filename, maintainer, ansi, pl, reviews, format, almirante, officials,
# Nearest to derived: pappy, disambiguation, lazar, word, numerals, envisage, datur, xiongnu,
# Nearest to smith: edn, zolt, amyraut, kroeber, lynn, bettors, brenda, chapman,
# Nearest to brother: carangi, adultery, majesty, stillborn, sustaining, orders, demiurge, fulvia,
# Epoch 3/10 Iteration: 19100 Avg. Training loss: 3.9144 0.1400 sec/batch
# Epoch 3/10 Iteration: 19200 Avg. Training loss: 3.8877 0.1386 sec/batch
# Epoch 3/10 Iteration: 19300 Avg. Training loss: 3.8980 0.1385 sec/batch
# Epoch 3/10 Iteration: 19400 Avg. Training loss: 3.7546 0.1383 sec/batch
# Epoch 3/10 Iteration: 19500 Avg. Training loss: 3.9097 0.1379 sec/batch
# Epoch 3/10 Iteration: 19600 Avg. Training loss: 3.9518 0.1382 sec/batch
# Epoch 3/10 Iteration: 19700 Avg. Training loss: 3.9290 0.1382 sec/batch
# Epoch 3/10 Iteration: 19800 Avg. Training loss: 3.9483 0.1387 sec/batch
# Epoch 3/10 Iteration: 19900 Avg. Training loss: 3.9407 0.1383 sec/batch
# Epoch 3/10 Iteration: 20000 Avg. Training loss: 3.9234 0.1382 sec/batch
# Nearest to known: referred, called, analyte, considered, regarded, zealand, wallabies, dehydroepiandrosterone,
# Nearest to people: soldiery, perctarit, inhabitants, mulatto, kills, hindi, jirga, autodidacts,
# Nearest to during: end, ended, brief, early, telescopic, demarco, beginning, amplification,
# Nearest to who: nuit, funkadelic, caa, technologies, prajna, milking, karelia, kalamazoo,
# Nearest to new: octagon, cement, implants, separated, fend, devour, micromachining, scalars,
# Nearest to states: chromodynamics, kingdom, gaut, cenotaph, volante, barents, establishments, nations,
# Nearest to three: incorrect, uganda, asatru, wakayama, filesystems, rud, corsa, kariba,
# Nearest to these: pecos, enjoying, maverick, nationwide, choreographed, qurra, hanun, thermo,
# Nearest to bill: impression, uninfected, loopholes, dislodged, thro, holborn, yukio, native,
# Nearest to alternative: medical, chorale, gooseberry, vitamins, earnest, atrocities, treating, omar,
# Nearest to arts: sciences, tfl, vibrant, dionysius, planckian, martial, tter, yoho,
# Nearest to applied: generalizes, textrm, inorganic, gillies, proctor, describing, amici, university,
# Nearest to file: filename, maintainer, ansi, officials, pl, reviews, almirante, spitz,
# Nearest to derived: pappy, lazar, disambiguation, word, envisage, custody, datur, xiongnu,
# Nearest to smith: edn, zolt, kroeber, amyraut, bettors, kanons, brenda, lynn,
# Nearest to brother: carangi, adultery, stillborn, demiurge, fulvia, orders, majesty, sustaining,
# Epoch 3/10 Iteration: 20100 Avg. Training loss: 3.8899 0.1395 sec/batch
# Epoch 3/10 Iteration: 20200 Avg. Training loss: 3.8743 0.1383 sec/batch
# Epoch 3/10 Iteration: 20300 Avg. Training loss: 3.6587 0.1389 sec/batch
# Epoch 3/10 Iteration: 20400 Avg. Training loss: 3.8972 0.1380 sec/batch
# Epoch 3/10 Iteration: 20500 Avg. Training loss: 3.8607 0.1384 sec/batch
# Epoch 3/10 Iteration: 20600 Avg. Training loss: 3.8719 0.1380 sec/batch
# Epoch 3/10 Iteration: 20700 Avg. Training loss: 3.8640 0.1380 sec/batch
# Epoch 3/10 Iteration: 20800 Avg. Training loss: 3.7971 0.1386 sec/batch
# Epoch 3/10 Iteration: 20900 Avg. Training loss: 3.9213 0.1380 sec/batch
# Epoch 3/10 Iteration: 21000 Avg. Training loss: 3.9055 0.1377 sec/batch
# Nearest to known: referred, called, analyte, considered, regarded, zealand, dehydroepiandrosterone, wallabies,
# Nearest to people: soldiery, perctarit, inhabitants, hindi, taiwan, mulatto, bad, jirga,
# Nearest to during: end, ended, early, brief, telescopic, beginning, throughout, amplification,
# Nearest to who: nuit, funkadelic, prajna, caa, technologies, mountain, milking, shortfalls,
# Nearest to new: octagon, cement, implants, fend, devour, separated, caracas, micromachining,
# Nearest to states: chromodynamics, kingdom, gaut, volante, cenotaph, america, establishments, u,
# Nearest to three: incorrect, uganda, asatru, wakayama, filesystems, rud, corsa, umpire,
# Nearest to these: pecos, maverick, enjoying, nationwide, choreographed, qurra, deteriorated, hanun,
# Nearest to bill: impression, uninfected, loopholes, dislodged, merle, thro, yukio, holborn,
# Nearest to alternative: medical, chorale, treating, gooseberry, atrocities, omar, earnest, megali,
# Nearest to arts: tfl, sciences, vibrant, planckian, tter, yoho, polymer, dionysius,
# Nearest to applied: generalizes, textrm, proctor, describing, gillies, inorganic, suspensions, choreography,
# Nearest to file: filename, maintainer, pl, officials, ansi, reviews, spitz, almirante,
# Nearest to derived: pappy, lazar, word, envisage, datur, disambiguation, niva, meaning,
# Nearest to smith: edn, zolt, amyraut, kroeber, bettors, lynn, kanons, franciscus,
# Nearest to brother: carangi, demiurge, adultery, stillborn, fulvia, orders, majesty, sustaining,
# Epoch 3/10 Iteration: 21100 Avg. Training loss: 3.9020 0.1396 sec/batch
# Epoch 3/10 Iteration: 21200 Avg. Training loss: 3.8896 0.1381 sec/batch
# Epoch 3/10 Iteration: 21300 Avg. Training loss: 3.9390 0.1381 sec/batch
# Epoch 3/10 Iteration: 21400 Avg. Training loss: 3.8601 0.1381 sec/batch
# Epoch 3/10 Iteration: 21500 Avg. Training loss: 3.8907 0.1380 sec/batch
# Epoch 3/10 Iteration: 21600 Avg. Training loss: 3.8667 0.1382 sec/batch
# Epoch 3/10 Iteration: 21700 Avg. Training loss: 3.9036 0.1374 sec/batch
# Epoch 3/10 Iteration: 21800 Avg. Training loss: 3.9476 0.1382 sec/batch
# Epoch 3/10 Iteration: 21900 Avg. Training loss: 3.9614 0.1381 sec/batch
# Epoch 3/10 Iteration: 22000 Avg. Training loss: 3.7682 0.1380 sec/batch
# Nearest to known: referred, called, analyte, regarded, considered, zealand, wallabies, described,
# Nearest to people: soldiery, perctarit, taiwan, inhabitants, kills, dropouts, mulatto, americans,
# Nearest to during: end, ended, early, brief, demarco, throughout, telescopic, cloudy,
# Nearest to who: nuit, funkadelic, technologies, prajna, caa, milking, karelia, kalamazoo,
# Nearest to new: octagon, cement, implants, devour, caracas, fend, micromachining, preprocessing,
# Nearest to states: chromodynamics, kingdom, gaut, volante, nations, cenotaph, barents, establishments,
# Nearest to three: incorrect, uganda, asatru, wakayama, filesystems, rud, corsa, umpire,
# Nearest to these: pecos, maverick, enjoying, nationwide, deteriorated, choreographed, qurra, hanun,
# Nearest to bill: impression, uninfected, loopholes, merle, yukio, thro, holborn, dislodged,
# Nearest to alternative: medical, chorale, atrocities, gooseberry, treating, megali, incubated, omar,
# Nearest to arts: sciences, tfl, vibrant, tter, planckian, dionysius, yoho, polymer,
# Nearest to applied: generalizes, describing, proctor, gillies, choreography, inorganic, textrm, university,
# Nearest to file: filename, maintainer, pl, ansi, reviews, officials, bounding, almirante,
# Nearest to derived: word, meaning, disambiguation, pappy, lazar, datur, envisage, custody,
# Nearest to smith: edn, zolt, amyraut, kroeber, bettors, chapman, kanons, lynn,
# Nearest to brother: carangi, adultery, fulvia, stillborn, orders, divorced, demiurge, daggers,
# ...
# Nearest to derived: derives, comes, meaning, derive, acquired, applied, styling, corrupted,
# Nearest to smith: halleck, edn, almanack, zolt, ximinez, kanons, doubling, hay,
# Nearest to brother: younger, son, sister, baptisms, goiter, argus, resinous, loosed,
# Epoch 10/10 Iteration: 83100 Avg. Training loss: 3.7069 0.1288 sec/batch
# Epoch 10/10 Iteration: 83200 Avg. Training loss: 3.7480 0.1278 sec/batch
# Epoch 10/10 Iteration: 83300 Avg. Training loss: 3.7213 0.1279 sec/batch
# Epoch 10/10 Iteration: 83400 Avg. Training loss: 3.6632 0.1277 sec/batch
# Epoch 10/10 Iteration: 83500 Avg. Training loss: 3.4741 0.1278 sec/batch
# Epoch 10/10 Iteration: 83600 Avg. Training loss: 3.6435 0.1280 sec/batch
# Epoch 10/10 Iteration: 83700 Avg. Training loss: 3.6569 0.1278 sec/batch
# Epoch 10/10 Iteration: 83800 Avg. Training loss: 3.6851 0.1277 sec/batch
# Epoch 10/10 Iteration: 83900 Avg. Training loss: 3.6862 0.1281 sec/batch
# Epoch 10/10 Iteration: 84000 Avg. Training loss: 3.5589 0.1277 sec/batch
# Nearest to known: called, referred, considered, documented, regarded, probably, established, understood,
# Nearest to people: soldiery, inhabitants, residents, persons, shorthand, mede, resolvers, musicians,
# Nearest to during: throughout, late, beginning, early, end, prior, brief, saw,
# Nearest to who: funkadelic, almanack, publications, nuit, podcast, pessimism, prajna, superfamilies,
# Nearest to new: octagon, cement, micromachining, famagusta, devour, implants, intercollegiate, underside,
# Nearest to states: kingdom, nations, emirates, u, united, chromodynamics, us, volante,
# Nearest to three: incorrect, filesystems, problems, biotechnology, wakayama, rud, asatru, deformities,
# Nearest to these: maverick, pecos, hanun, enjoying, nationwide, thermo, comical, typhon,
# Nearest to bill: holborn, bills, dislodged, impression, yukio, condemns, calcutta, mcghee,
# Nearest to alternative: conventional, treating, hexer, alternate, traditional, lipstick, flush, piped,
# Nearest to arts: art, performing, martial, tter, faro, karate, supercomputing, sciences,
# Nearest to applied: refer, refers, describe, derived, referred, boerhaave, proctor, uses,
# Nearest to file: files, filename, maintainer, pl, beavis, bounding, conclusion, formats,
# Nearest to derived: derives, comes, meaning, derive, acquired, styling, applied, implies,
# Nearest to smith: halleck, almanack, edn, zolt, ximinez, elmira, kanons, curl,
# Nearest to brother: younger, son, sister, argus, baptisms, goiter, dis, actuality,
# Epoch 10/10 Iteration: 84100 Avg. Training loss: 3.6782 0.1288 sec/batch
# Epoch 10/10 Iteration: 84200 Avg. Training loss: 3.6875 0.1281 sec/batch
# Epoch 10/10 Iteration: 84300 Avg. Training loss: 3.7050 0.1279 sec/batch
# Epoch 10/10 Iteration: 84400 Avg. Training loss: 3.6820 0.1281 sec/batch
# Epoch 10/10 Iteration: 84500 Avg. Training loss: 3.7111 0.1279 sec/batch
# Epoch 10/10 Iteration: 84600 Avg. Training loss: 3.6771 0.1282 sec/batch
# Epoch 10/10 Iteration: 84700 Avg. Training loss: 3.6852 0.1278 sec/batch
# Epoch 10/10 Iteration: 84800 Avg. Training loss: 3.6303 0.1279 sec/batch
# Epoch 10/10 Iteration: 84900 Avg. Training loss: 3.7028 0.1289 sec/batch
# Epoch 10/10 Iteration: 85000 Avg. Training loss: 3.7339 0.1280 sec/batch
# Nearest to known: called, referred, considered, documented, regarded, established, probably, perhaps,
# Nearest to people: soldiery, inhabitants, persons, shorthand, americans, residents, musicians, autodidacts,
# Nearest to during: throughout, late, early, beginning, prior, before, saw, end,
# Nearest to who: funkadelic, almanack, publications, nuit, podcast, pessimism, prajna, superfamilies,
# Nearest to new: octagon, micromachining, cement, famagusta, devour, intercollegiate, gaines, underside,
# Nearest to states: kingdom, nations, u, united, emirates, chromodynamics, us, volante,
# Nearest to three: incorrect, problems, filesystems, biotechnology, wakayama, rud, deformities, pelican,
# Nearest to these: maverick, pecos, hanun, enjoying, thermo, nationwide, comical, wiping,
# Nearest to bill: holborn, dislodged, bills, impression, yukio, condemns, calcutta, hansie,
# Nearest to alternative: conventional, hexer, treating, alternate, flush, traditional, lipstick, intended,
# Nearest to arts: art, performing, tter, martial, faro, renowned, karate, potencies,
# Nearest to applied: refer, refers, referred, describe, derived, synonymous, uses, boerhaave,
# Nearest to file: files, filename, maintainer, pl, bounding, beavis, conclusion, formats,
# Nearest to derived: derives, comes, derive, meaning, acquired, applied, implies, styling,
# Nearest to smith: halleck, almanack, edn, ximinez, zolt, elmira, tata, doubling,
# Nearest to brother: son, younger, sister, actuality, argus, hornby, goiter, resinous,
# Epoch 10/10 Iteration: 85100 Avg. Training loss: 3.7718 0.1294 sec/batch
# Epoch 10/10 Iteration: 85200 Avg. Training loss: 3.6576 0.1280 sec/batch
# Epoch 10/10 Iteration: 85300 Avg. Training loss: 3.6359 0.1280 sec/batch
# Epoch 10/10 Iteration: 85400 Avg. Training loss: 3.6251 0.1281 sec/batch
# Epoch 10/10 Iteration: 85500 Avg. Training loss: 3.7229 0.1280 sec/batch
# Epoch 10/10 Iteration: 85600 Avg. Training loss: 3.6737 0.1277 sec/batch
# Epoch 10/10 Iteration: 85700 Avg. Training loss: 3.7444 0.1280 sec/batch
# Epoch 10/10 Iteration: 85800 Avg. Training loss: 3.6395 0.1280 sec/batch
# Epoch 10/10 Iteration: 85900 Avg. Training loss: 3.6716 0.1281 sec/batch
# Epoch 10/10 Iteration: 86000 Avg. Training loss: 3.6694 0.1282 sec/batch
# Nearest to known: called, referred, considered, documented, regarded, probably, understood, described,
# Nearest to people: soldiery, inhabitants, americans, shorthand, residents, musicians, obdurodon, mede,
# Nearest to during: throughout, late, beginning, prior, early, saw, end, ended,
# Nearest to who: funkadelic, almanack, nuit, publications, pessimism, podcast, waking, superfamilies,
# Nearest to new: octagon, micromachining, famagusta, cement, devour, intercollegiate, gaines, implants,
# Nearest to states: kingdom, nations, united, u, emirates, chromodynamics, volante, us,
# Nearest to three: incorrect, problems, filesystems, biotechnology, wakayama, deformities, rud, pelican,
# Nearest to these: maverick, pecos, hanun, enjoying, thermo, comical, nationwide, typhon,
# Nearest to bill: holborn, condemns, dislodged, yukio, impression, bills, calcutta, mcghee,
# Nearest to alternative: conventional, hexer, alternate, treating, flush, traditional, lipstick, alternatives,
# Nearest to arts: art, performing, tter, martial, faro, potencies, submit, karate,
# Nearest to applied: refer, refers, derived, describe, referred, synonymous, proctor, boerhaave,
# Nearest to file: files, filename, maintainer, pl, conclusion, beavis, bounding, posek,
# Nearest to derived: derives, comes, derive, meaning, acquired, applied, styling, ran,
# Nearest to smith: halleck, almanack, zolt, edn, ximinez, doubling, elmira, tata,
# Nearest to brother: younger, son, sister, elder, goiter, resinous, nephew, fulvia,
# Epoch 10/10 Iteration: 86100 Avg. Training loss: 3.6234 0.1286 sec/batch
# Epoch 10/10 Iteration: 86200 Avg. Training loss: 3.7028 0.1278 sec/batch
# Epoch 10/10 Iteration: 86300 Avg. Training loss: 3.7251 0.1280 sec/batch
# Epoch 10/10 Iteration: 86400 Avg. Training loss: 3.6198 0.1282 sec/batch
# Epoch 10/10 Iteration: 86500 Avg. Training loss: 3.6208 0.1278 sec/batch
# Epoch 10/10 Iteration: 86600 Avg. Training loss: 3.7079 0.1279 sec/batch
# Epoch 10/10 Iteration: 86700 Avg. Training loss: 3.7098 0.1278 sec/batch
# Epoch 10/10 Iteration: 86800 Avg. Training loss: 3.7547 0.1283 sec/batch
# Epoch 10/10 Iteration: 86900 Avg. Training loss: 3.6940 0.1281 sec/batch
# Epoch 10/10 Iteration: 87000 Avg. Training loss: 3.6315 0.1280 sec/batch
# Nearest to known: called, referred, considered, documented, regarded, understood, probably, described,
# Nearest to people: soldiery, inhabitants, americans, residents, shorthand, persons, musicians, mede,
# Nearest to during: throughout, late, prior, before, early, beginning, end, ended,
# Nearest to who: funkadelic, almanack, nuit, publications, pessimism, podcast, waking, superfamilies,
# Nearest to new: octagon, cement, micromachining, famagusta, intercollegiate, devour, implants, underside,
# Nearest to states: kingdom, nations, united, u, chromodynamics, emirates, us, cenotaph,
# Nearest to three: incorrect, filesystems, problems, biotechnology, wakayama, pelican, asatru, uganda,
# Nearest to these: maverick, pecos, hanun, enjoying, thermo, comical, typhon, nationwide,
# Nearest to bill: holborn, condemns, dislodged, impression, bills, yukio, mcghee, defiance,
# Nearest to alternative: conventional, hexer, treating, alternate, lipstick, flush, confocal, piped,
# Nearest to arts: art, martial, performing, tter, faro, submit, karate, potencies,
# Nearest to applied: refer, refers, derived, describe, boerhaave, proctor, synonymous, referred,
# Nearest to file: files, filename, maintainer, beavis, formats, bounding, pl, posek,
# Nearest to derived: derives, comes, derive, meaning, acquired, applied, styling, whose,
# Nearest to smith: halleck, almanack, edn, zolt, doubling, hay, tata, ximinez,
# Nearest to brother: younger, son, sister, goiter, resinous, fulvia, dis, elder,
# Epoch 10/10 Iteration: 87100 Avg. Training loss: 3.7313 0.1291 sec/batch
# Epoch 10/10 Iteration: 87200 Avg. Training loss: 3.7032 0.1279 sec/batch
# Epoch 10/10 Iteration: 87300 Avg. Training loss: 3.7196 0.1282 sec/batch
# Epoch 10/10 Iteration: 87400 Avg. Training loss: 3.7130 0.1279 sec/batch
# Epoch 10/10 Iteration: 87500 Avg. Training loss: 3.7173 0.1279 sec/batch
# Epoch 10/10 Iteration: 87600 Avg. Training loss: 3.6179 0.1281 sec/batch
# Epoch 10/10 Iteration: 87700 Avg. Training loss: 3.6466 0.1283 sec/batch
# Epoch 10/10 Iteration: 87800 Avg. Training loss: 3.6847 0.1280 sec/batch
# Epoch 10/10 Iteration: 87900 Avg. Training loss: 3.6857 0.1283 sec/batch
# Epoch 10/10 Iteration: 88000 Avg. Training loss: 3.6578 0.1279 sec/batch
# Nearest to known: called, referred, considered, documented, regarded, probably, understood, described,
# Nearest to people: soldiery, inhabitants, residents, americans, persons, shorthand, mede, scientists,
# Nearest to during: throughout, late, beginning, prior, early, before, end, ended,
# Nearest to who: funkadelic, almanack, nuit, publications, pessimism, waking, podcast, superfamilies,
# Nearest to new: octagon, micromachining, cement, famagusta, devour, intercollegiate, implants, caracas,
# Nearest to states: kingdom, nations, u, united, chromodynamics, us, emirates, state,
# Nearest to three: incorrect, filesystems, biotechnology, problems, wakayama, asatru, rud, deformities,
# Nearest to these: maverick, pecos, hanun, thermo, comical, enjoying, nationwide, typhon,
# Nearest to bill: bills, holborn, dislodged, impression, mcghee, condemns, wyche, yukio,
# Nearest to alternative: conventional, treating, alternate, hexer, flush, piped, accepted, lipstick,
# Nearest to arts: art, performing, tter, submit, faro, martial, potencies, ellicott,
# Nearest to applied: refer, refers, describe, derived, proctor, referred, boerhaave, synonymous,
# Nearest to file: files, filename, maintainer, bounding, posek, beavis, conclusion, pl,
# Nearest to derived: derives, derive, comes, meaning, acquired, corrupted, styling, applied,
# Nearest to smith: halleck, almanack, tata, edn, zolt, doubling, ximinez, umlauts,
# Nearest to brother: son, younger, sister, elder, fulvia, baptisms, argus, goiter,
# Epoch 10/10 Iteration: 88100 Avg. Training loss: 3.6390 0.1290 sec/batch
# Epoch 10/10 Iteration: 88200 Avg. Training loss: 3.4592 0.1281 sec/batch
# Epoch 10/10 Iteration: 88300 Avg. Training loss: 3.6248 0.1283 sec/batch
# Epoch 10/10 Iteration: 88400 Avg. Training loss: 3.6924 0.1279 sec/batch
# Epoch 10/10 Iteration: 88500 Avg. Training loss: 3.7864 0.1284 sec/batch
# Epoch 10/10 Iteration: 88600 Avg. Training loss: 3.7113 0.1279 sec/batch
# Epoch 10/10 Iteration: 88700 Avg. Training loss: 3.7827 0.1279 sec/batch
# Epoch 10/10 Iteration: 88800 Avg. Training loss: 3.7447 0.1282 sec/batch
# Epoch 10/10 Iteration: 88900 Avg. Training loss: 3.6808 0.1281 sec/batch
# Epoch 10/10 Iteration: 89000 Avg. Training loss: 3.6075 0.1281 sec/batch
# Nearest to known: called, referred, considered, regarded, documented, probably, understood, perhaps,
# Nearest to people: soldiery, inhabitants, americans, residents, persons, shorthand, directors, members,
# Nearest to during: throughout, late, beginning, prior, end, early, since, before,
# Nearest to who: funkadelic, almanack, nuit, publications, pessimism, waking, podcast, superfamilies,
# Nearest to new: octagon, cement, micromachining, famagusta, devour, intercollegiate, implants, caracas,
# Nearest to states: kingdom, nations, united, u, emirates, chromodynamics, us, volante,
# Nearest to three: incorrect, filesystems, biotechnology, wakayama, problems, asatru, rud, deformities,
# Nearest to these: maverick, pecos, hanun, thermo, comical, nationwide, enjoying, typhon,
# Nearest to bill: bills, holborn, dislodged, condemns, yukio, impression, wyche, legislation,
# Nearest to alternative: conventional, treating, hexer, alternate, lipstick, flush, piped, freude,
# Nearest to arts: art, performing, martial, tter, faro, submit, karate, sport,
# Nearest to applied: refer, refers, derived, describe, boerhaave, proctor, ast, synonymous,
# Nearest to file: files, filename, maintainer, posek, beavis, formats, bounding, pl,
# Nearest to derived: derives, comes, derive, meaning, acquired, applied, corrupted, deriving,
# Nearest to smith: halleck, almanack, edn, doubling, elmira, ximinez, zolt, umlauts,
# Nearest to brother: younger, son, sister, elder, dis, baptisms, goiter, resinous,
# Epoch 10/10 Iteration: 89100 Avg. Training loss: 3.6443 0.1293 sec/batch
# Epoch 10/10 Iteration: 89200 Avg. Training loss: 3.6802 0.1283 sec/batch
# Epoch 10/10 Iteration: 89300 Avg. Training loss: 3.6872 0.1279 sec/batch
# Epoch 10/10 Iteration: 89400 Avg. Training loss: 3.7051 0.1283 sec/batch
# Epoch 10/10 Iteration: 89500 Avg. Training loss: 3.5949 0.1281 sec/batch
# Epoch 10/10 Iteration: 89600 Avg. Training loss: 3.4578 0.1280 sec/batch
# Epoch 10/10 Iteration: 89700 Avg. Training loss: 3.7240 0.1281 sec/batch
# Epoch 10/10 Iteration: 89800 Avg. Training loss: 3.6034 0.1280 sec/batch
# Epoch 10/10 Iteration: 89900 Avg. Training loss: 3.6795 0.1280 sec/batch
# Epoch 10/10 Iteration: 90000 Avg. Training loss: 3.6682 0.1281 sec/batch
# Nearest to known: called, referred, considered, regarded, documented, probably, understood, described,
# Nearest to people: soldiery, inhabitants, residents, americans, persons, speak, shorthand, mede,
# Nearest to during: throughout, prior, late, beginning, ended, early, end, before,
# Nearest to who: funkadelic, almanack, nuit, publications, pessimism, podcast, waking, superfamilies,
# Nearest to new: octagon, cement, famagusta, micromachining, intercollegiate, implants, devour, caracas,
# Nearest to states: kingdom, nations, u, emirates, united, chromodynamics, volante, us,
# Nearest to three: incorrect, filesystems, problems, wakayama, biotechnology, deformities, asatru, rud,
# Nearest to these: maverick, pecos, hanun, thermo, enjoying, comical, typhon, wiping,
# Nearest to bill: bills, holborn, dislodged, yukio, condemns, mcghee, wyche, deirdre,
# Nearest to alternative: conventional, treating, hexer, alternate, lipstick, flush, accepted, intended,
# Nearest to arts: art, martial, performing, tter, karate, sport, faro, aikido,
# Nearest to applied: refer, refers, derived, describe, ast, proctor, boerhaave, synonymous,
# Nearest to file: files, filename, formats, maintainer, format, posek, bounding, spitz,
# Nearest to derived: derives, comes, derive, meaning, applied, acquired, implies, corrupted,
# Nearest to smith: halleck, almanack, doubling, edn, elmira, zolt, umlauts, ximinez,
# Nearest to brother: younger, son, sister, dis, elder, fulvia, goiter, resinous,
# Epoch 10/10 Iteration: 90100 Avg. Training loss: 3.6329 0.1289 sec/batch
# Epoch 10/10 Iteration: 90200 Avg. Training loss: 3.7094 0.1279 sec/batch
# Epoch 10/10 Iteration: 90300 Avg. Training loss: 3.7492 0.1282 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
